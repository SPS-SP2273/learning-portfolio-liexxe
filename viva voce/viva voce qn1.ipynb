# %% [markdown]
# # Introduction

# %% [markdown]
# # Tasks

# %% [markdown]
# ## Getting Started

# %%
os.chdir('/Users/liesephong/Desktop/learning-portfolio-liexxe/viva voce')

# %%
from test_kit import test

# %%
import os
import glob
os.getcwd()
# Out:
# '/Users/liesephong/Desktop/learning-portfolio-liexxe/viva voce'

# %%
os.chdir('/Users/liesephong/Desktop/learning-portfolio-liexxe/viva voce/person-files')

# %%
glob.glob('*')
# Out:
# ['person_00149.txt',
#  'person_00161.txt',
#  'person_00175.txt',
#  'person_00439.txt',
#  'person_00405.txt',
#  'person_00363.txt',
#  'person_00377.txt',
#  'person_00411.txt',
#  'person_00388.txt',
#  'person_00217.txt',
#  'person_00203.txt',
#  'person_00029.txt',
#  'person_00015.txt',
#  'person_00001.txt',
#  'person_00000.txt',
#  'person_00014.txt',
#  'person_00028.txt',
#  'person_00202.txt',
#  'person_00216.txt',
#  'person_00389.txt',
#  'person_00376.txt',
#  'person_00410.txt',
#  'person_00404.txt',
#  'person_00362.txt',
#  'person_00438.txt',
#  'person_00174.txt',
#  'person_00160.txt',
#  'person_00148.txt',
#  'person_00176.txt',
#  'person_00162.txt',
#  'person_00189.txt',
#  'person_00348.txt',
#  'person_00412.txt',
#  'person_00374.txt',
#  'person_00360.txt',
#  'person_00406.txt',
#  'person_00228.txt',
#  'person_00200.txt',
#  'person_00214.txt',
#  'person_00002.txt',
#  'person_00016.txt',
#  'person_00017.txt',
#  'person_00003.txt',
# ...

# %%
#testing person 27
with open('person_00027.txt') as file: #remember to put .txt!
    file_content=file.read()
#print(file_content)
test(file_content)
# Out:
# True

# %%
#testing person 17
with open('person_00017.txt') as file:
    file_content=file.read()
#print(file_content)
test(file_content)
# Out:
# False

# %%
#testing person 37
with open('person_00017.txt') as file:
    file_content=file.read()
#print(file_content)
test(file_content)
# Out:
# False

# %% [markdown]
# ## Create a function

# %%
def get_genome1(person_id):
    filename=f'person_{person_id:05d}.txt'
    with open(filename) as file:
        file_content=file.read()
    print(file_content)

# %%
get_genome1(2)
# Out:
# ...

# %%
def get_genome2(person_id):
    filename=f'person_{person_id:05d}.txt'
    with open(filename) as file:
        file_content=file.read()
    print(test(file_content))

# %%
get_genome2(2)
# Out:
# False

# %%
for i in range(0,100): #python takes 100-1 (not inclusive)
    get_genome2(i)
# Out:
# False
# True
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %% [markdown]
# ## Random Testing

# %%
#method 1 using shuffle to retrieve 100 non-repeating numbers
import numpy as np
# Generate an array of numbers from 0 to 499
numbers = np.arange(500)

# Shuffle the array of numbers
np.random.shuffle(numbers)

# Take the first 100 numbers from the shuffled array
numbers = numbers[:100]

print(numbers)
# Out:
# [ 84 438 459 461 407 460 143  78 329 482 251 380 330 306 425 455 126 231
#  235 365 392 479 269  92  48 416 332  11 246 436  59 272  82 441 295 122
#  258  91 256 471 428 287 225 372 149 192  18 179 247 282 376 497 370 418
#   63 394 319 435 127 275  17 238 110 250 355  71 144  69 164 429 216 448
#  352 374 427   1 189 173 462 484 136   4  40 132 228 226  88 167 364  57
#   12 367 331 317 301 140 303 307 472  13]

# %%
#method 2 using random.choice to retrieve 100 non-repeating numbers
numbers = np.random.choice(500,100,replace=False)
numbers
# Out:
# array([302, 249, 130, 148, 283, 439, 109, 152, 166, 347, 444, 259, 137,
#        244, 150, 281, 187, 147,  93, 467, 209, 369, 265, 160, 295, 465,
#        123, 367,  74,  78, 400, 215, 479, 278, 421, 336, 455, 454, 424,
#        391, 206, 332, 334, 185, 101, 274, 273, 389, 469, 189, 319, 352,
#         52, 234, 326, 458, 180, 194, 125, 135,   9, 318, 366, 464, 451,
#        472, 239, 220, 462, 213,  38, 492, 325, 364, 113,  65, 163, 490,
#        480, 165, 442, 177, 299, 214,  25, 422, 221,  61, 146, 471,  50,
#        179, 418,   7, 339, 291, 192, 258, 102, 114])

# %%
result=[]
for i in numbers:
    x=get_genome2(i)
    result.append(x)
# Out:
# False
# False
# False
# True
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# True
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False

# %%
x

# %%
sum(get_genome2(i))
# Out:
# False
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 sum(get_genome2(i))
#
# TypeError: 'NoneType' object is not iterable

# %%
sum(t)
# Out:
# 0

# %% [markdown]
# ## Pool Sampling
